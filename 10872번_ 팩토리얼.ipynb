# %% [markdown]
# # 팩토리얼
#
# 0보다 크거나 같은 정수 N이 주어진다. 이때, N!을 출력하는 프로그램을 작성하시오.

# %%
N = int(input())
a = 1

if N == 0:
  a = 1
else:
  for i in range(1,N+1):
    a = a * i

print(a)
# Out:
# 10
# 3628800
