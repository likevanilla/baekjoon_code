# %% [markdown]
# # A+B - 4
#
# 두 정수 A와 B를 입력받은 다음, A+B를 출력하는 프로그램을 작성하시오.

# %%
while True:
  try:
    A, B = input().split()
    print(int(A)+int(B))
  except:
    break
# Out:
# 1 1
# 2
# 1 1
# 2
# 1 1
# 2
# 1 1
# 2
# 1 1
# 2
