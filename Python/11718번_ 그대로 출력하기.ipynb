# %% [markdown]
# # 그대로 출력하기
#
# 입력 받은 대로 출력하는 프로그램을 작성하시오.

# %%
while True:
  try:
    a = input()
    if len(a) == 0:
      break
    print(a)
  except:
      break
# Out:
# hello
# hello
# hi
# hi
