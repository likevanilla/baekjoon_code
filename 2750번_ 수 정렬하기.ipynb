# %% [markdown]
# # 수 정렬하기
#
# N개의 수가 주어졌을 때, 이를 오름차순으로 정렬하는 프로그램을 작성하시오.

# %%
N = int(input())
lst = []

for i in range(N):
  lst.append(int(input()))

lst = sorted(lst)

for i in range(len(lst)):
  print(lst[i])
# Out:
# 5
# 4
# 2
# 3
# 5
# 1
# 1
# 2
# 3
# 4
# 5
