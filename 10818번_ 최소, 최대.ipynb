# %% [markdown]
# # 최소, 최대
#
# N개의 정수가 주어진다. 이때, 최솟값과 최댓값을 구하는 프로그램을 작성하시오.

# %%
N = int(input())

lst = input().split()

for i in range(N):
  lst.append(int(lst[i]))

del lst[:N]

print(min(lst), max(lst))
# Out:
# 5
# 20 10 35 30 7
# [20, 10, 35, 30, 7]
# 7 35
