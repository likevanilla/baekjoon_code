# %% [markdown]
# # 마이크로소프트 로고
#
# 마이크로소프트 로고를 예제 출력처럼 출력하는 프로그램을 작성하시오.

# %%
print('       _.-;;-._')
print('\'-..-\'|   ||   |')
print('\'-..-\'|_.-;;-._|')
print('\'-..-\'|   ||   |')
print('\'-..-\'|_.-\'\'-._|')
# Out:
#        _.-;;-._
# '-..-'|   ||   |
# '-..-'|_.-;;-._|
# '-..-'|   ||   |
# '-..-'|_.-''-._|
